# %%
import pandas as pd

df = pd.read_csv("data_5_frames_second.csv")

# %%
df.plot(figsize=(50,8))
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("data_10_frames_second.csv")

# %%
df.plot(figsize=(50,8))
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("data_3_frames_second.csv")
df.plot(figsize=(50,8))
# Out:
# <AxesSubplot:>
